# %% [markdown]
# # Extracting polygons
# This function uses the excel file created for Quad-G+ to crop the maps to the correct coordinates after its extracted the boundaries from the geotiff files and saved it as a shapefile.

# %%
# Import libraries
import pandas as pd
import os
import rasterio
import numpy as np
from rasterio.mask import mask
from shapely.geometry import box, Polygon
import geopandas as gpd
import matplotlib.pyplot as plt
from pathlib import Path
from skimage import morphology, feature, measure

# %%
# Takes DMS coordinate strings and converts them to decimal degrees
# Handles formats like "35 45" or "-120 07 30" that are found in excel file
def parse_dms(dms_str):
    # Remove any quotes
    dms_str = str(dms_str).strip('"\'')
    
    # Split into parts
    parts = dms_str.split()
    
    # Set defaults
    degrees = 0
    minutes = 0
    seconds = 0
    
    # Parse
    if len(parts) >= 1:
        degrees = float(parts[0])
    if len(parts) >= 2:
        minutes = float(parts[1])
    if len(parts) >= 3:
        seconds = float(parts[2])
    
    # Convert
    decimal = abs(degrees) + minutes/60 + seconds/3600
    return decimal if degrees >= 0 else -decimal

# Main function for field boundary extraction
# Takes a GeoTIFF and returns a shapefile with field boundaries
def extract_field_boundaries(geotiff_path, output_path=None):
    with rasterio.open(geotiff_path) as src:
        image = src.read()
        transform = src.transform
        crs = src.crs
        
        # Grayscale
        gray_image = np.mean(image, axis=0)
        
        # Boost the contrast
        p2, p98 = np.percentile(gray_image, (2, 98))
        gray_image = np.interp(gray_image, (p2, p98), (0, 1))
        
        # Convert to black and white
        binary = gray_image < 0.45
        
        # Get rid of tiny specks
        cleaned = morphology.remove_small_objects(binary, min_size=200)
        
        # Clean up
        cleaned = morphology.binary_opening(cleaned, morphology.square(2))
        cleaned = morphology.binary_closing(cleaned, morphology.square(4))
        
        # Find edges
        edges = feature.canny(
            cleaned,
            sigma=1.8,
            low_threshold=0.05,
            high_threshold=0.25
        )
        
        # Make edges thicker and fill gaps
        edges = morphology.dilation(edges, morphology.square(2))
        edges = morphology.closing(edges, morphology.square(5))
        
        # Clean up noise again
        edges = morphology.remove_small_objects(edges, min_size=200)
        
        # Find lines in the edge image
        contours = measure.find_contours(edges, 0.1)
        
        # Turn lines into actual polygons
        polygons = []
        for contour in contours:
            if len(contour) > 8:  # Skip tiny contours
                start = contour[0]
                end = contour[-1]
                dist = np.linalg.norm(start - end)
                
                # Close polygon if not already closed
                if dist < 30: 
                    contour = np.vstack([contour, contour[0]])
                
                # Convert coordinates
                geo_coords = [rasterio.transform.xy(transform, coord[0], coord[1]) 
                            for coord in contour]
                
                try:
                    poly = Polygon(geo_coords)
                    # Only keep reasonable sized polygons
                    if poly.is_valid and 800 < poly.area < 3e6: 
                        poly = poly.simplify(1.0, preserve_topology=True)
                        if poly.is_valid:
                            polygons.append(poly)
                except:
                    continue
        
        # Put into GeoDataFrame
        gdf = gpd.GeoDataFrame(geometry=polygons, crs=crs)
        
        # Remove big polygons (quad borders)
        large_polys = gdf[gdf.area > 1e6]
        field_polys = gdf[gdf.area <= 1e6]
        
        # Remove polygons inside other polygons (field text)
        not_contained = []
        for idx, row in field_polys.iterrows():
            poly1 = row.geometry
            is_contained = False
            for idx2, row2 in field_polys.iterrows():
                if idx != idx2:
                    poly2 = row2.geometry
                    if poly2.contains(poly1):
                        is_contained = True
                        break
            if not is_contained:
                not_contained.append(poly1)
        
        # Put the quad polygons back with text filtered out
        all_polygons = not_contained + large_polys.geometry.tolist()
        
        # New gdf with cleaned polygons
        gdf = gpd.GeoDataFrame(geometry=all_polygons, crs=crs)
        
        # Smooth out polygons
        gdf = gdf.buffer(0.8).buffer(-0.8)  
        gdf = gpd.GeoDataFrame(geometry=gdf, crs=crs)
        
        # Save
        if output_path:
            os.makedirs(os.path.dirname(output_path), exist_ok=True)
            gdf.to_file(output_path)
        
        return gdf

# Plot the shapefile
def plot_with_coordinates(shapefile_path):
    gdf = gpd.read_file(shapefile_path)
    
    fig, ax = plt.subplots(figsize=(15, 15))
    
    # Convert coordinates
    if gdf.crs != 'EPSG:3857':
        gdf = gdf.to_crs(epsg=3857)
    
    gdf.plot(ax=ax, 
            edgecolor='red',
            facecolor='none',
            linewidth=0.5)
    
    ax.grid(True)
    ax.tick_params(labelsize=8)
    
    return fig, ax

# Crops GeoTIFF to coordinates from excel then extracts field boundaries
def crop_and_extract(input_path, output_tif_path, output_shp_path, bounds):
    # Check file actually exists
    if not os.path.exists(input_path):
        print(f"Input file not found: {input_path}")
        return None
        
    # Open source file and print coordinate info
    with rasterio.open(input_path) as src:
        print(f"\nProcessing {os.path.basename(input_path)}:")
        print("Original image bounds:", src.bounds)
        print("Original image CRS:", src.crs)
        
        # Create bounding box
        bbox = box(bounds['west'], bounds['south'], bounds['east'], bounds['north'])
        bbox_gdf = gpd.GeoDataFrame(geometry=[bbox], crs='EPSG:4326')  # WGS84
        
        # Transform bbox to match crs
        bbox_gdf = bbox_gdf.to_crs(src.crs)
        bbox_transformed = bbox_gdf.geometry.values[0]
        
        print("Transformed crop bounds:", bbox_transformed.bounds)
        
        try:
            # Crop
            out_image, out_transform = mask(src, [bbox_transformed], crop=True)
            
            print("Cropped image shape:", out_image.shape)
            
            # Update metadata
            out_meta = src.meta.copy()
            out_meta.update({
                "height": out_image.shape[1],
                "width": out_image.shape[2],
                "transform": out_transform
            })
            
            # Output directory
            os.makedirs(os.path.dirname(output_tif_path), exist_ok=True)
            
            # Save cropped image
            with rasterio.open(output_tif_path, "w", **out_meta) as dest:
                dest.write(out_image)
        
        except ValueError as e:
            print(f"Error during cropping: {e}")
            print("Check if the coordinates are within the image bounds and in the correct order.")
            return None
    
    # Extract field boundaries from cropped image
    try:
        gdf = extract_field_boundaries(output_tif_path, output_shp_path)
        return gdf
    except Exception as e:
        print(f"Error during field boundary extraction: {e}")
        return None

# Process GeoTIFF files from the excel sheet
# Has resume capability so you don't have to start over if something goes wrong (processing_results.csv)
def batch_process_geotiffs(excel_path, input_dir=".", output_dir="outputs", resume=True):
    # Make output directory
    os.makedirs(output_dir, exist_ok=True)
    
    # Check csv for already processed files
    results_path = os.path.join(output_dir, 'processing_results.csv')
    existing_results = []
    processed_files = set()
    
    if resume and os.path.exists(results_path):
        try:
            results_df = pd.read_csv(results_path)
            existing_results = results_df.to_dict('records')
            
            for result in existing_results:
                if result['status'] == 'Success':
                    processed_files.add(result['file_name'])
            
            print(f"Found {len(processed_files)} previously processed files.")
        except Exception as e:
            print(f"Error reading existing results file: {e}")
    
    # Load excel file
    try:
        df = pd.read_excel(excel_path)
        print(f"Read {len(df)} entries from {excel_path}")
    except Exception as e:
        print(f"Error reading Excel file: {e}")
        return
    
    # Check columns
    required_columns = ["File Name", "South", "North", "West", "East"]
    
    missing_columns = [col for col in required_columns if col not in df.columns]
    if missing_columns:
        print(f"Missing required columns in Excel file: {missing_columns}")
        return
    
    # Check if resuming
    results = existing_results.copy() if resume else []
    
    # Keep track how many processed
    processed_count = 0
    
    # Process rows excel file
    for idx, row in df.iterrows():
        file_name = row['File Name']
        
        # Skip if in csv already
        if resume and file_name in processed_files:
            print(f"Skipping already processed file: {file_name}")
            continue
            
        print(f"\n{'='*50}")
        print(f"Processing entry {idx+1}/{len(df)}: {file_name}")
        
        # File paths
        input_file = os.path.join(input_dir, file_name)
        base_name = Path(file_name).stem
        
        # Convert coordinates
        try:
            south = parse_dms(str(row['South']))
            north = parse_dms(str(row['North']))
            west = parse_dms(str(row['West']))
            east = parse_dms(str(row['East']))
            
            print("\nConverted coordinates:")
            print(f"South: {south}")
            print(f"North: {north}")
            print(f"West: {west}")
            print(f"East: {east}")
            
            # Output file paths
            output_tif_path = os.path.join(output_dir, f"{base_name}_cropped.tif")
            output_shp_path = os.path.join(output_dir, f"{base_name}_cropped.shp")
            output_png_path = os.path.join(output_dir, f"{base_name}_cropped.png")
            
            # Bounds
            bounds = {
                'south': south,
                'north': north,
                'west': west,
                'east': east
            }
            
            # Process
            gdf = crop_and_extract(input_file, output_tif_path, output_shp_path, bounds)
            
            status = "Success" if gdf is not None else "Failed"
            
            # Plot
            if gdf is not None:
                fig, ax = plot_with_coordinates(output_shp_path)
                plt.savefig(output_png_path, dpi=300, bbox_inches='tight')
                plt.close()
            
            # Record in csv
            results.append({
                'file_name': file_name,
                'status': status,
                'output_tif': output_tif_path if gdf is not None else None,
                'output_shp': output_shp_path if gdf is not None else None,
                'output_png': output_png_path if gdf is not None else None
            })
            
            processed_count += 1
            
            print(f"Processing status: {status}")
            
            # Save csv after each file
            results_df = pd.DataFrame(results)
            results_df.to_csv(results_path, index=False)
            
        except Exception as e:
            print(f"Error processing {file_name}: {e}")
            results.append({
                'file_name': file_name,
                'status': 'Error',
                'error_message': str(e),
                'output_tif': None,
                'output_shp': None,
                'output_png': None
            })
            # Save progress after errors
            results_df = pd.DataFrame(results)
            results_df.to_csv(results_path, index=False)
    
    # Print summary
    print(f"\n{'='*50}")
    print("Processing Summary:")
    success_count = sum(1 for r in results if r['status'] == 'Success')
    print(f"Total files in Excel: {len(df)}")
    print(f"Previously processed: {len(processed_files)}")
    print(f"Newly processed this run: {processed_count}")
    print(f"Total successful: {success_count}")
    print(f"Total failed: {len(results) - success_count}")
    
    # Save
    results_df = pd.DataFrame(results)
    results_df.to_csv(results_path, index=False)
    print(f"Summary saved to: {results_path}")
    
    return results_df

# Visualize shapefiles
def plot_all_shapefiles(shapefile_dir, output_path=None, base_crs='EPSG:3857'):
    shapefile_paths = list(Path(shapefile_dir).glob("*.shp"))
    
    if not shapefile_paths:
        print(f"No shapefiles found in {shapefile_dir}")
        return None, None
    
    print(f"Found {len(shapefile_paths)} shapefiles")
    
    all_gdfs = []
    
    for shp_path in shapefile_paths:
        try:
            gdf = gpd.read_file(shp_path)
            
            filename = shp_path.stem
            gdf['source_file'] = filename
            
            # Check crs
            if gdf.crs != base_crs:
                gdf = gdf.to_crs(base_crs)
                
            all_gdfs.append(gdf)
            print(f"Loaded: {filename}")
        except Exception as e:
            print(f"Error loading {shp_path}: {e}")
    
    if not all_gdfs:
        print("No valid shapefiles could be loaded")
        return None, None
    
    # Combine files
    combined_gdf = gpd.GeoDataFrame(pd.concat(all_gdfs, ignore_index=True))
    
    # Plot
    fig, ax = plt.subplots(figsize=(20, 20))
    combined_gdf.plot(ax=ax, edgecolor='blue', facecolor='none', linewidth=0.8)
    ax.grid(True, linestyle='--', alpha=0.5)
    
    ax.set_title(f"Combined Field Boundaries", fontsize=14)

    
    # Save
    if output_path:
        output_dir = os.path.dirname(output_path)
        if output_dir and not os.path.exists(output_dir):
            os.makedirs(output_dir)
        plt.savefig(output_path, dpi=300, bbox_inches='tight')
        print(f"Combined visualization saved to: {output_path}")
    
    return fig, ax

# %%
excel_path = "excel_map_info/quad_maps_1969.xlsx"  # Path to your Excel file
input_dir = "quad_maps/maps_1969"                # Directory where your GeoTIFF files are located
output_dir = "outputs/outputs_1969"         # Directory to save outputs
    
    
# Run the batch processing
results = batch_process_geotiffs(excel_path, input_dir, output_dir, resume=True)
# Out:
# Read 52 entries from excel_map_info/quad_maps_1969.xlsx
#
# ==================================================
# Processing entry 1/52: 69KN5036_Poly.tif
#
# Converted coordinates:
# South: 35.75
# North: 35.875
# West: -120.125
# East: -120.0
#
# Processing 69KN5036_Poly.tif:
# Original image bounds: BoundingBox(left=-6845.491678735414, bottom=-1337.9296014289866, right=7166.130376689578, top=15735.97613588989)
# Original image CRS: PROJCS["unnamed",GEOGCS["NAD27",DATUM["North_American_Datum_1927",SPHEROID["Clarke 1866",6378206.4,294.978698213898,AUTHORITY["EPSG","7008"]],AUTHORITY["EPSG","6267"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4267"]],PROJECTION["Polyconic"],PARAMETER["latitude_of_origin",35.75],PARAMETER["central_meridian",-120.0625],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Transformed crop bounds: (-5564.870126976284, 5.778656491383042, 5740.901211980603, 13875.6627628585)
# Cropped image shape: (4, 4557, 3715)
# Processing status: Success
#
# ==================================================
# Processing entry 2/52: 69KN5037_Poly.tif
#
# Converted coordinates:
# South: 35.75
# North: 35.875
# West: -120.0
# East: -119.875
#
# Processing 69KN5037_Poly.tif:
# Original image bounds: BoundingBox(left=-6963.680053127883, bottom=-2315.2504049309937, right=7286.129323529435, top=14988.740763908158)
# Original image CRS: PROJCS["unnamed",GEOGCS["NAD27",DATUM["North_American_Datum_1927",SPHEROID["Clarke 1866",6378206.4,294.978698213898,AUTHORITY["EPSG","7008"]],AUTHORITY["EPSG","6267"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4267"]],PROJECTION["Polyconic"],PARAMETER["latitude_of_origin",35.75],PARAMETER["central_meridian",-119.9375],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Transformed crop bounds: (-5565.284553635373, 6.049572652476733, 5740.592901928773, 13875.74895115961)
# Cropped image shape: (4, 4565, 3721)
# Processing status: Success
#
# ==================================================
# Processing entry 3/52: 69KN5038_Poly.tif
#
# Converted coordinates:
# South: 35.75
# North: 35.875
# West: -119.875
# East: -119.75
# Input file not found: quad_maps/maps_1969/69KN5038_Poly.tif
# Processing status: Failed
#
# ==================================================
# Processing entry 4/52: 69KN5039_Poly.tif
#
# Converted coordinates:
# South: 35.75
# North: 35.875
# West: -119.75
# East: -119.625
# Input file not found: quad_maps/maps_1969/69KN5039_Poly.tif
# Processing status: Failed
#
# ==================================================
# Processing entry 5/52: 69KN5040_Poly.tif
#
# Converted coordinates:
# South: 35.75
# North: 35.875
# West: -119.625
# East: -119.5
#
# Processing 69KN5040_Poly.tif:
# Original image bounds: BoundingBox(left=-6678.94905545638, bottom=-1527.897477123799, right=7474.736662576639, top=15652.630668560858)
# Original image CRS: PROJCS["unnamed",GEOGCS["NAD27",DATUM["North_American_Datum_1927",SPHEROID["Clarke 1866",6378206.4,294.978698213898,AUTHORITY["EPSG","7008"]],AUTHORITY["EPSG","6267"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4267"]],PROJECTION["Polyconic"],PARAMETER["latitude_of_origin",35.75],PARAMETER["central_meridian",-119.5625],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Transformed crop bounds: (-5566.391328606499, 6.462261945113, 5739.303008937465, 13876.066160805276)
# Cropped image shape: (4, 4556, 3714)
# Processing status: Success
#
# ==================================================
# Processing entry 6/52: 69KN5041_Poly.tif
#
# Converted coordinates:
# South: 35.75
# North: 35.875
# West: -119.5
# East: -119.375
#
# Processing 69KN5041_Poly.tif:
# Original image bounds: BoundingBox(left=-7015.555037011077, bottom=-2242.888868768465, right=7165.736165902778, top=15008.327848786043)
# Original image CRS: PROJCS["unnamed",GEOGCS["NAD27",DATUM["North_American_Datum_1927",SPHEROID["Clarke 1866",6378206.4,294.978698213898,AUTHORITY["EPSG","7008"]],AUTHORITY["EPSG","6267"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4267"]],PROJECTION["Polyconic"],PARAMETER["latitude_of_origin",35.75],PARAMETER["central_meridian",-119.4375],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Transformed crop bounds: (-5566.881912394902, 6.712963089443931, 5738.835397956314, 13876.056477127779)
# Cropped image shape: (4, 4559, 3717)
# Processing status: Success
#
# ==================================================
# Processing entry 7/52: 69KN5042_Poly.tif
#
# Converted coordinates:
# South: 35.75
# North: 35.875
# West: -119.375
# East: -119.25
#
# Processing 69KN5042_Poly.tif:
# Original image bounds: BoundingBox(left=-6948.391349061933, bottom=-2104.191043325911, right=7260.728632626598, top=15173.63657139424)
# Original image CRS: PROJCS["unnamed",GEOGCS["NAD27",DATUM["North_American_Datum_1927",SPHEROID["Clarke 1866",6378206.4,294.978698213898,AUTHORITY["EPSG","7008"]],AUTHORITY["EPSG","6267"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4267"]],PROJECTION["Polyconic"],PARAMETER["latitude_of_origin",35.75],PARAMETER["central_meridian",-119.3125],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Transformed crop bounds: (-5567.349368857579, 6.834488386538528, 5738.367757350442, 13876.047237343819)
# Cropped image shape: (4, 4561, 3718)
# Processing status: Success
#
# ==================================================
# Processing entry 8/52: 69KN5043_Poly.tif
#
# Converted coordinates:
# South: 35.75
# North: 35.875
# West: -119.25
# East: -119.125
#
# Processing 69KN5043_Poly.tif:
# Original image bounds: BoundingBox(left=-6907.396741047826, bottom=-2108.402252564736, right=7090.059831664196, top=14958.698676127819)
# Original image CRS: PROJCS["unnamed",GEOGCS["NAD27",DATUM["North_American_Datum_1927",SPHEROID["Clarke 1866",6378206.4,294.978698213898,AUTHORITY["EPSG","7008"]],AUTHORITY["EPSG","6267"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4267"]],PROJECTION["Polyconic"],PARAMETER["latitude_of_origin",35.75],PARAMETER["central_meridian",-119.1875],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Transformed crop bounds: (-5567.816855476208, 6.9555933177271045, 5737.900399476404, 13876.081331800202)
# Cropped image shape: (4, 4560, 3717)
# Processing status: Success
#
# ==================================================
# Processing entry 9/52: 69KN5044_Poly.tif
#
# Converted coordinates:
# South: 35.75
# North: 35.875
# West: -119.125
# East: -119.0
#
# Processing 69KN5044_Poly.tif:
# Original image bounds: BoundingBox(left=-7040.783886157416, bottom=-2224.917398205929, right=7235.201204554629, top=15049.51013927982)
# Original image CRS: PROJCS["unnamed",GEOGCS["NAD27",DATUM["North_American_Datum_1927",SPHEROID["Clarke 1866",6378206.4,294.978698213898,AUTHORITY["EPSG","7008"]],AUTHORITY["EPSG","6267"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4267"]],PROJECTION["Polyconic"],PARAMETER["latitude_of_origin",35.75],PARAMETER["central_meridian",-119.0625],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Transformed crop bounds: (-5568.28419314608, 6.971742090655729, 5737.432947398494, 13876.115672957443)
# Cropped image shape: (4, 4571, 3726)
# Processing status: Success
#
# ==================================================
# Processing entry 10/52: 69KN5136_Poly.tif
#
# Converted coordinates:
# South: 35.625
# North: 35.75
# West: -120.125
# East: -120.0
#
# Processing 69KN5136_Poly.tif:
# Original image bounds: BoundingBox(left=-6933.972217214376, bottom=-1580.2536515790125, right=7113.128943114321, top=15519.771119542682)
# Original image CRS: PROJCS["unnamed",GEOGCS["NAD27",DATUM["North_American_Datum_1927",SPHEROID["Clarke 1866",6378206.4,294.978698213898,AUTHORITY["EPSG","7008"]],AUTHORITY["EPSG","6267"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4267"]],PROJECTION["Polyconic"],PARAMETER["latitude_of_origin",35.625],PARAMETER["central_meridian",-120.0625],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Transformed crop bounds: (-5573.301387000558, 5.459355331412786, 5750.080945677629, 13874.954641660453)
# Cropped image shape: (4, 4558, 3721)
# Processing status: Success
#
# ==================================================
# Processing entry 11/52: 69KN5137_Poly.tif
#
# Converted coordinates:
# South: 35.625
# North: 35.75
# West: -120.0
# East: -119.875
#
# Processing 69KN5137_Poly.tif:
# Original image bounds: BoundingBox(left=-6993.57435321992, bottom=-1635.6917171686036, right=7182.504033797671, top=15566.603789583489)
# Original image CRS: PROJCS["unnamed",GEOGCS["NAD27",DATUM["North_American_Datum_1927",SPHEROID["Clarke 1866",6378206.4,294.978698213898,AUTHORITY["EPSG","7008"]],AUTHORITY["EPSG","6267"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4267"]],PROJECTION["Polyconic"],PARAMETER["latitude_of_origin",35.625],PARAMETER["central_meridian",-119.9375],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Transformed crop bounds: (-5573.756108138354, 5.717486481520676, 5749.727640962124, 13875.034835714107)
# Cropped image shape: (4, 4561, 3724)
# Processing status: Success
#
# ==================================================
# Processing entry 12/52: 69KN5138_Poly.tif
#
# Converted coordinates:
# South: 35.625
# North: 35.75
# West: -119.875
# East: -119.75
#
# Processing 69KN5138_Poly.tif:
# Original image bounds: BoundingBox(left=-6906.864816765757, bottom=-2253.877285016544, right=7233.742306277397, top=14889.291591210927)
# Original image CRS: PROJCS["unnamed",GEOGCS["NAD27",DATUM["North_American_Datum_1927",SPHEROID["Clarke 1866",6378206.4,294.978698213898,AUTHORITY["EPSG","7008"]],AUTHORITY["EPSG","6267"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4267"]],PROJECTION["Polyconic"],PARAMETER["latitude_of_origin",35.625],PARAMETER["central_meridian",-119.8125],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Transformed crop bounds: (-5574.109260412366, 5.83767264058316, 5749.373817364928, 13875.115333149495)
# Cropped image shape: (4, 4565, 3727)
# Processing status: Success
#
# ==================================================
# Processing entry 13/52: 69KN5139_Poly.tif
#
# Converted coordinates:
# South: 35.625
# North: 35.75
# West: -119.75
# East: -119.625
#
# Processing 69KN5139_Poly.tif:
# Original image bounds: BoundingBox(left=-6987.9216297790435, bottom=-2091.7583647537467, right=7110.876447846841, top=15025.177425272686)
# Original image CRS: PROJCS["unnamed",GEOGCS["NAD27",DATUM["North_American_Datum_1927",SPHEROID["Clarke 1866",6378206.4,294.978698213898,AUTHORITY["EPSG","7008"]],AUTHORITY["EPSG","6267"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4267"]],PROJECTION["Polyconic"],PARAMETER["latitude_of_origin",35.625],PARAMETER["central_meridian",-119.6875],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Transformed crop bounds: (-5574.46293168757, 5.957761456263861, 5748.825617097281, 13875.365919892092)
# Cropped image shape: (4, 4573, 3734)
# Processing status: Success
#
# ==================================================
# Processing entry 14/52: 69KN5140_Poly.tif
#
# Converted coordinates:
# South: 35.625
# North: 35.75
# West: -119.625
# East: -119.5
#
# Processing 69KN5140_Poly.tif:
# Original image bounds: BoundingBox(left=-6843.45468040167, bottom=-2034.6460496654436, right=7117.784010104489, top=14985.549856101748)
# Original image CRS: PROJCS["unnamed",GEOGCS["NAD27",DATUM["North_American_Datum_1927",SPHEROID["Clarke 1866",6378206.4,294.978698213898,AUTHORITY["EPSG","7008"]],AUTHORITY["EPSG","6267"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4267"]],PROJECTION["Polyconic"],PARAMETER["latitude_of_origin",35.625],PARAMETER["central_meridian",-119.5625],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Transformed crop bounds: (-5575.01079631313, 6.222234547045684, 5748.277915588953, 13875.615995523392)
# Cropped image shape: (4, 4567, 3729)
# Processing status: Success
#
# ==================================================
# Processing entry 15/52: 69KN5141_Poly.tif
#
# Converted coordinates:
# South: 35.625
# North: 35.75
# West: -119.5
# East: -119.375
#
# Processing 69KN5141_Poly.tif:
# Original image bounds: BoundingBox(left=-6833.731470478116, bottom=-2059.9880830606617, right=7143.77762376585, top=14953.2091438234)
# Original image CRS: PROJCS["unnamed",GEOGCS["NAD27",DATUM["North_American_Datum_1927",SPHEROID["Clarke 1866",6378206.4,294.978698213898,AUTHORITY["EPSG","7008"]],AUTHORITY["EPSG","6267"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4267"]],PROJECTION["Polyconic"],PARAMETER["latitude_of_origin",35.625],PARAMETER["central_meridian",-119.4375],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Transformed crop bounds: (-5575.5581627909505, 6.486226038113289, 5747.784140738648, 13875.736924887204)
# Cropped image shape: (4, 4574, 3735)
# Processing status: Success
#
# ==================================================
# Processing entry 16/52: 69KN5142_Poly.tif
#
# Converted coordinates:
# South: 35.625
# North: 35.75
# West: -119.375
# East: -119.25
#
# Processing 69KN5142_Poly.tif:
# Original image bounds: BoundingBox(left=-7018.99491876182, bottom=-1826.52189940499, right=7375.380923148061, top=15596.809770783522)
# Original image CRS: PROJCS["unnamed",GEOGCS["NAD27",DATUM["North_American_Datum_1927",SPHEROID["Clarke 1866",6378206.4,294.978698213898,AUTHORITY["EPSG","7008"]],AUTHORITY["EPSG","6267"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4267"]],PROJECTION["Polyconic"],PARAMETER["latitude_of_origin",35.625],PARAMETER["central_meridian",-119.3125],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Transformed crop bounds: (-5576.0517363127, 6.644971821084233, 5747.290326157801, 13875.857433848732)
# Cropped image shape: (4, 4566, 3729)
# Processing status: Success
#
# ==================================================
# Processing entry 17/52: 69KN5143_Poly.tif
#
# Converted coordinates:
# South: 35.625
# North: 35.75
# West: -119.25
# East: -119.125
#
# Processing 69KN5143_Poly.tif:
# Original image bounds: BoundingBox(left=-6785.015253006662, bottom=-2732.8493229809155, right=7251.12237431083, top=14970.442112513547)
# Original image CRS: PROJCS["unnamed",GEOGCS["NAD27",DATUM["North_American_Datum_1927",SPHEROID["Clarke 1866",6378206.4,294.978698213898,AUTHORITY["EPSG","7008"]],AUTHORITY["EPSG","6267"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4267"]],PROJECTION["Polyconic"],PARAMETER["latitude_of_origin",35.625],PARAMETER["central_meridian",-119.1875],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Transformed crop bounds: (-5576.545349555487, 6.803721474654509, 5746.852851970705, 13875.872986922683)
# Cropped image shape: (4, 4563, 3725)
# Processing status: Success
#
# ==================================================
# Processing entry 18/52: 69KN5144_Poly.tif
#
# Converted coordinates:
# South: 35.625
# North: 35.75
# West: -119.125
# East: -119.0
#
# Processing 69KN5144_Poly.tif:
# Original image bounds: BoundingBox(left=-6914.985380315638, bottom=-2544.784212197974, right=7134.084639046838, top=15183.22692094924)
# Original image CRS: PROJCS["unnamed",GEOGCS["NAD27",DATUM["North_American_Datum_1927",SPHEROID["Clarke 1866",6378206.4,294.978698213898,AUTHORITY["EPSG","7008"]],AUTHORITY["EPSG","6267"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4267"]],PROJECTION["Polyconic"],PARAMETER["latitude_of_origin",35.625],PARAMETER["central_meridian",-119.0625],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Transformed crop bounds: (-5576.982737932363, 6.871525537956177, 5746.41548553555, 13875.887968444973)
# Cropped image shape: (4, 4577, 3738)
# Processing status: Success
#
# ==================================================
# Processing entry 19/52: 69KN5237_Poly.tif
#
# Converted coordinates:
# South: 35.5
# North: 35.625
# West: -120.0
# East: -119.875
#
# Processing 69KN5237_Poly.tif:
# Original image bounds: BoundingBox(left=-6835.283644312281, bottom=-2797.468586533414, right=7165.1145743023, top=14876.857596627608)
# Original image CRS: PROJCS["unnamed",GEOGCS["NAD27",DATUM["North_American_Datum_1927",SPHEROID["Clarke 1866",6378206.4,294.978698213898,AUTHORITY["EPSG","7008"]],AUTHORITY["EPSG","6267"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4267"]],PROJECTION["Polyconic"],PARAMETER["latitude_of_origin",35.5],PARAMETER["central_meridian",-119.9375],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Transformed crop bounds: (-5582.200391145281, 5.385449245131187, 5758.835504905485, 13874.450841192136)
# Cropped image shape: (4, 4568, 3736)
# Processing status: Success
#
# ==================================================
# Processing entry 20/52: 69KN5238_Poly.tif
#
# Converted coordinates:
# South: 35.5
# North: 35.625
# West: -119.875
# East: -119.75
#
# Processing 69KN5238_Poly.tif:
# Original image bounds: BoundingBox(left=-6812.291832040857, bottom=-2730.940457583034, right=7130.042168650025, top=14924.083050373974)
# Original image CRS: PROJCS["unnamed",GEOGCS["NAD27",DATUM["North_American_Datum_1927",SPHEROID["Clarke 1866",6378206.4,294.978698213898,AUTHORITY["EPSG","7008"]],AUTHORITY["EPSG","6267"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4267"]],PROJECTION["Polyconic"],PARAMETER["latitude_of_origin",35.5],PARAMETER["central_meridian",-119.8125],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Transformed crop bounds: (-5582.598605998112, 5.545231863219809, 5758.436066195883, 13874.57048047914)
# Cropped image shape: (4, 4566, 3734)
# Processing status: Success
#
# ==================================================
# Processing entry 21/52: 69KN5239_Poly.tif
#
# Converted coordinates:
# South: 35.5
# North: 35.625
# West: -119.75
# East: -119.625
#
# Processing 69KN5239_Poly.tif:
# Original image bounds: BoundingBox(left=-6951.925594594248, bottom=-2579.2269965312335, right=7199.243411495323, top=15194.057847062904)
# Original image CRS: PROJCS["unnamed",GEOGCS["NAD27",DATUM["North_American_Datum_1927",SPHEROID["Clarke 1866",6378206.4,294.978698213898,AUTHORITY["EPSG","7008"]],AUTHORITY["EPSG","6267"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4267"]],PROJECTION["Polyconic"],PARAMETER["latitude_of_origin",35.5],PARAMETER["central_meridian",-119.6875],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Transformed crop bounds: (-5582.997843231128, 5.704514367708046, 5757.8301454448, 13874.834257152195)
# Cropped image shape: (4, 4565, 3733)
# Processing status: Success
#
# ==================================================
# Processing entry 22/52: 69KN5240_Poly.tif
#
# Converted coordinates:
# South: 35.5
# North: 35.625
# West: -119.625
# East: -119.5
#
# Processing 69KN5240_Poly.tif:
# Original image bounds: BoundingBox(left=-6754.27613306247, bottom=-2702.196970262812, right=7350.425896395774, top=15097.247468382957)
# Original image CRS: PROJCS["unnamed",GEOGCS["NAD27",DATUM["North_American_Datum_1927",SPHEROID["Clarke 1866",6378206.4,294.978698213898,AUTHORITY["EPSG","7008"]],AUTHORITY["EPSG","6267"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4267"]],PROJECTION["Polyconic"],PARAMETER["latitude_of_origin",35.5],PARAMETER["central_meridian",-119.5625],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Transformed crop bounds: (-5583.603412652088, 5.982213208957787, 5757.225465271054, 13875.09755285983)
# Cropped image shape: (4, 4547, 3718)
# Processing status: Success
#
# ==================================================
# Processing entry 23/52: 69KN5241_Poly.tif
#
# Converted coordinates:
# South: 35.5
# North: 35.625
# West: -119.5
# East: -119.375
#
# Processing 69KN5241_Poly.tif:
# Original image bounds: BoundingBox(left=-6850.074019449343, bottom=-2104.65552693463, right=7126.487902399593, top=15521.527404678634)
# Original image CRS: PROJCS["unnamed",GEOGCS["NAD27",DATUM["North_American_Datum_1927",SPHEROID["Clarke 1866",6378206.4,294.978698213898,AUTHORITY["EPSG","7008"]],AUTHORITY["EPSG","6267"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4267"]],PROJECTION["Polyconic"],PARAMETER["latitude_of_origin",35.5],PARAMETER["central_meridian",-119.4375],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Transformed crop bounds: (-5584.207742070457, 6.259457585867637, 5756.705440713299, 13875.255671299488)
# Cropped image shape: (4, 4573, 3739)
# Processing status: Success
#
# ==================================================
# Processing entry 24/52: 69KN5242_Poly.tif
#
# Converted coordinates:
# South: 35.5
# North: 35.625
# West: -119.375
# East: -119.25
#
# Processing 69KN5242_Poly.tif:
# Original image bounds: BoundingBox(left=-6963.951677938365, bottom=-2786.6514263084136, right=7262.717158992371, top=15069.517395470692)
# Original image CRS: PROJCS["unnamed",GEOGCS["NAD27",DATUM["North_American_Datum_1927",SPHEROID["Clarke 1866",6378206.4,294.978698213898,AUTHORITY["EPSG","7008"]],AUTHORITY["EPSG","6267"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4267"]],PROJECTION["Polyconic"],PARAMETER["latitude_of_origin",35.5],PARAMETER["central_meridian",-119.3125],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Transformed crop bounds: (-5584.727518840038, 6.455375166274328, 5756.18536585594, 13875.413793559359)
# Cropped image shape: (4, 4571, 3738)
# Processing status: Success
#
# ==================================================
# Processing entry 25/52: 69KN5243_Poly.tif
#
# Converted coordinates:
# South: 35.5
# North: 35.625
# West: -119.25
# East: -119.125
#
# Processing 69KN5243_Poly.tif:
# Original image bounds: BoundingBox(left=-6933.079252565259, bottom=-2791.534279179279, right=7020.697636310259, top=14851.6952508949)
# Original image CRS: PROJCS["unnamed",GEOGCS["NAD27",DATUM["North_American_Datum_1927",SPHEROID["Clarke 1866",6378206.4,294.978698213898,AUTHORITY["EPSG","7008"]],AUTHORITY["EPSG","6267"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4267"]],PROJECTION["Polyconic"],PARAMETER["latitude_of_origin",35.5],PARAMETER["central_meridian",-119.1875],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Transformed crop bounds: (-5585.247345364839, 6.651718820993603, 5755.77788107048, 13875.48104174921)
# Cropped image shape: (4, 4572, 3739)
# Processing status: Success
#
# ==================================================
# Processing entry 26/52: 69KN5244_Poly.tif
#
# Converted coordinates:
# South: 35.5
# North: 35.625
# West: -119.125
# East: -119.0
#
# Processing 69KN5244_Poly.tif:
# Original image bounds: BoundingBox(left=-6806.146696168935, bottom=-2829.691475650925, right=7180.0959723138385, top=14861.55629599377)
# Original image CRS: PROJCS["unnamed",GEOGCS["NAD27",DATUM["North_American_Datum_1927",SPHEROID["Clarke 1866",6378206.4,294.978698213898,AUTHORITY["EPSG","7008"]],AUTHORITY["EPSG","6267"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4267"]],PROJECTION["Polyconic"],PARAMETER["latitude_of_origin",35.5],PARAMETER["central_meridian",-119.0625],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Transformed crop bounds: (-5585.654679116742, 6.7711920722495424, 5755.3707066511615, 13875.547415745375)
# Cropped image shape: (4, 4575, 3742)
# Processing status: Success
#
# ==================================================
# Processing entry 27/52: 69KN5339_Poly.tif
#
# Converted coordinates:
# South: 35.375
# North: 35.5
# West: -119.75
# East: -119.625
#
# Processing 69KN5339_Poly.tif:
# Original image bounds: BoundingBox(left=-6788.178494763145, bottom=-2746.2062134060907, right=7209.9115217235, top=14927.750621050222)
# Original image CRS: PROJCS["unnamed",GEOGCS["NAD27",DATUM["North_American_Datum_1927",SPHEROID["Clarke 1866",6378206.4,294.978698213898,AUTHORITY["EPSG","7008"]],AUTHORITY["EPSG","6267"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4267"]],PROJECTION["Polyconic"],PARAMETER["latitude_of_origin",35.375],PARAMETER["central_meridian",-119.6875],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Transformed crop bounds: (-5591.770541994303, 5.564921999144607, 5766.7048577502965, 13874.30304296062)
# Cropped image shape: (4, 4562, 3737)
# Processing status: Success
#
# ==================================================
# Processing entry 28/52: 69KN5340_Poly.tif
#
# Converted coordinates:
# South: 35.375
# North: 35.5
# West: -119.625
# East: -119.5
#
# Processing 69KN5340_Poly.tif:
# Original image bounds: BoundingBox(left=-6858.728740731591, bottom=-2116.778749617406, right=7296.4049634934345, top=15656.9605632065)
# Original image CRS: PROJCS["unnamed",GEOGCS["NAD27",DATUM["North_American_Datum_1927",SPHEROID["Clarke 1866",6378206.4,294.978698213898,AUTHORITY["EPSG","7008"]],AUTHORITY["EPSG","6267"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4267"]],PROJECTION["Polyconic"],PARAMETER["latitude_of_origin",35.375],PARAMETER["central_meridian",-119.5625],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Transformed crop bounds: (-5592.271710152515, 5.76261465392831, 5766.203968486837, 13874.57952149786)
# Cropped image shape: (4, 4561, 3736)
# Processing status: Success
#
# ==================================================
# Processing entry 29/52: 69KN5341_Poly.tif
#
# Converted coordinates:
# South: 35.375
# North: 35.5
# West: -119.5
# East: -119.375
#
# Processing 69KN5341_Poly.tif:
# Original image bounds: BoundingBox(left=-7107.678477749884, bottom=-2680.4368724876585, right=6988.000104838539, top=15049.99553676133)
# Original image CRS: PROJCS["unnamed",GEOGCS["NAD27",DATUM["North_American_Datum_1927",SPHEROID["Clarke 1866",6378206.4,294.978698213898,AUTHORITY["EPSG","7008"]],AUTHORITY["EPSG","6267"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4267"]],PROJECTION["Polyconic"],PARAMETER["latitude_of_origin",35.375],PARAMETER["central_meridian",-119.4375],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Transformed crop bounds: (-5592.772350773413, 5.9597943244250775, 5765.714181590576, 13874.774780421289)
# Cropped image shape: (4, 4568, 3742)
# Processing status: Success
#
# ==================================================
# Processing entry 30/52: 69KN5342_Poly.tif
#
# Converted coordinates:
# South: 35.375
# North: 35.5
# West: -119.375
# East: -119.25
#
# Processing 69KN5342_Poly.tif:
# Original image bounds: BoundingBox(left=-7073.03652464033, bottom=-2116.938039025654, right=7071.0510233037885, top=15660.298177349605)
# Original image CRS: PROJCS["unnamed",GEOGCS["NAD27",DATUM["North_American_Datum_1927",SPHEROID["Clarke 1866",6378206.4,294.978698213898,AUTHORITY["EPSG","7008"]],AUTHORITY["EPSG","6267"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4267"]],PROJECTION["Polyconic"],PARAMETER["latitude_of_origin",35.375],PARAMETER["central_meridian",-119.3125],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Transformed crop bounds: (-5593.261971223583, 6.091889549751024, 5765.224638985878, 13874.970465355493)
# Cropped image shape: (4, 4570, 3743)
# Processing status: Success
#
# ==================================================
# Processing entry 31/52: 69KN5343_Poly.tif
#
# Converted coordinates:
# South: 35.375
# North: 35.5
# West: -119.25
# East: -119.125
#
# Processing 69KN5343_Poly.tif:
# Original image bounds: BoundingBox(left=-7000.791821036876, bottom=-2897.680909385861, right=7074.9132664716135, top=14856.28087628138)
# Original image CRS: PROJCS["unnamed",GEOGCS["NAD27",DATUM["North_American_Datum_1927",SPHEROID["Clarke 1866",6378206.4,294.978698213898,AUTHORITY["EPSG","7008"]],AUTHORITY["EPSG","6267"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4267"]],PROJECTION["Polyconic"],PARAMETER["latitude_of_origin",35.375],PARAMETER["central_meridian",-119.1875],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Transformed crop bounds: (-5593.751346821461, 6.224424915646585, 5764.821838925409, 13875.0894224639)
# Cropped image shape: (4, 4571, 3744)
# Processing status: Success
#
# ==================================================
# Processing entry 32/52: 69KN5344_Poly.tif
#
# Converted coordinates:
# South: 35.375
# North: 35.5
# West: -119.125
# East: -119.0
#
# Processing 69KN5344_Poly.tif:
# Original image bounds: BoundingBox(left=-6838.849938245784, bottom=-2776.024729935354, right=7171.996335323288, top=14884.017041105013)
# Original image CRS: PROJCS["unnamed",GEOGCS["NAD27",DATUM["North_American_Datum_1927",SPHEROID["Clarke 1866",6378206.4,294.978698213898,AUTHORITY["EPSG","7008"]],AUTHORITY["EPSG","6267"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4267"]],PROJECTION["Polyconic"],PARAMETER["latitude_of_origin",35.375],PARAMETER["central_meridian",-119.0625],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Transformed crop bounds: (-5594.1539802695515, 6.356595034284454, 5764.419306329294, 13875.207202682675)
# Cropped image shape: (4, 4569, 3743)
# Processing status: Success
#
# ==================================================
# Processing entry 33/52: 69KN5441_Poly.tif
#
# Converted coordinates:
# South: 35.25
# North: 35.375
# West: -119.5
# East: -119.375
#
# Processing 69KN5441_Poly.tif:
# Original image bounds: BoundingBox(left=-6793.727621348583, bottom=-2805.626101238535, right=7188.511348061959, top=14820.32174109599)
# Original image CRS: PROJCS["unnamed",GEOGCS["NAD27",DATUM["North_American_Datum_1927",SPHEROID["Clarke 1866",6378206.4,294.978698213898,AUTHORITY["EPSG","7008"]],AUTHORITY["EPSG","6267"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4267"]],PROJECTION["Polyconic"],PARAMETER["latitude_of_origin",35.25],PARAMETER["central_meridian",-119.4375],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Transformed crop bounds: (-5601.310020307466, 5.660096617000809, 5774.695770895384, 13874.120593888756)
# Cropped image shape: (4, 4564, 3744)
# Processing status: Success
#
# ==================================================
# Processing entry 34/52: 69KN5442_Poly.tif
#
# Converted coordinates:
# South: 35.25
# North: 35.375
# West: -119.375
# East: -119.25
#
# Processing 69KN5442_Poly.tif:
# Original image bounds: BoundingBox(left=-6598.473334865984, bottom=-2822.274879815126, right=7482.147463744196, top=14897.738306440144)
# Original image CRS: PROJCS["unnamed",GEOGCS["NAD27",DATUM["North_American_Datum_1927",SPHEROID["Clarke 1866",6378206.4,294.978698213898,AUTHORITY["EPSG","7008"]],AUTHORITY["EPSG","6267"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4267"]],PROJECTION["Polyconic"],PARAMETER["latitude_of_origin",35.25],PARAMETER["central_meridian",-119.3125],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Transformed crop bounds: (-5601.769384424265, 5.72836889427373, 5774.236862107574, 13874.252511060484)
# Cropped image shape: (4, 4567, 3745)
# Processing status: Success
#
# ==================================================
# Processing entry 35/52: 69KN5443_Poly.tif
#
# Converted coordinates:
# South: 35.25
# North: 35.375
# West: -119.25
# East: -119.125
#
# Processing 69KN5443_Poly.tif:
# Original image bounds: BoundingBox(left=-6798.111865643665, bottom=-2621.28598117826, right=7221.677139215535, top=15062.97323171306)
# Original image CRS: PROJCS["unnamed",GEOGCS["NAD27",DATUM["North_American_Datum_1927",SPHEROID["Clarke 1866",6378206.4,294.978698213898,AUTHORITY["EPSG","7008"]],AUTHORITY["EPSG","6267"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4267"]],PROJECTION["Polyconic"],PARAMETER["latitude_of_origin",35.25],PARAMETER["central_meridian",-119.1875],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Transformed crop bounds: (-5602.228207038496, 5.797094569689016, 5773.838779713734, 13874.38417254214)
# Cropped image shape: (4, 4565, 3745)
# Processing status: Success
#
# ==================================================
# Processing entry 36/52: 69KN5444_Poly.tif
#
# Converted coordinates:
# South: 35.25
# North: 35.375
# West: -119.125
# East: -119.0
#
# Processing 69KN5444_Poly.tif:
# Original image bounds: BoundingBox(left=-6748.187303378887, bottom=-2676.21014309318, right=7224.266031610123, top=15002.415967098037)
# Original image CRS: PROJCS["unnamed",GEOGCS["NAD27",DATUM["North_American_Datum_1927",SPHEROID["Clarke 1866",6378206.4,294.978698213898,AUTHORITY["EPSG","7008"]],AUTHORITY["EPSG","6267"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4267"]],PROJECTION["Polyconic"],PARAMETER["latitude_of_origin",35.25],PARAMETER["central_meridian",-119.0625],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Transformed crop bounds: (-5602.626107367269, 5.941940291432782, 5773.440922188914, 13874.514957310588)
# Cropped image shape: (4, 4574, 3752)
# Processing status: Success
#
# ==================================================
# Processing entry 37/52: 69KN5445_Poly.tif
#
# Converted coordinates:
# South: 35.25
# North: 35.375
# West: -119.0
# East: -118.875
# Input file not found: quad_maps/maps_1969/69KN5445_Poly.tif
# Processing status: Failed
#
# ==================================================
# Processing entry 38/52: 69KN5446_Poly.tif
#
# Converted coordinates:
# South: 35.25
# North: 35.375
# West: -118.875
# East: -118.75
#
# Processing 69KN5446_Poly.tif:
# Original image bounds: BoundingBox(left=-6981.67607279537, bottom=-2897.9111557272263, right=7042.84908098648, top=14775.66650987991)
# Original image CRS: PROJCS["unnamed",GEOGCS["NAD27",DATUM["North_American_Datum_1927",SPHEROID["Clarke 1866",6378206.4,294.978698213898,AUTHORITY["EPSG","7008"]],AUTHORITY["EPSG","6267"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4267"]],PROJECTION["Polyconic"],PARAMETER["latitude_of_origin",35.25],PARAMETER["central_meridian",-118.8125],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Transformed crop bounds: (-5603.294689960659, 6.081823321302118, 5772.898806560129, 13874.467373610649)
# Cropped image shape: (4, 4562, 3742)
# Processing status: Success
#
# ==================================================
# Processing entry 39/52: 69KN5542_Poly.tif
#
# Converted coordinates:
# South: 35.125
# North: 35.25
# West: -119.375
# East: -119.25
#
# Processing 69KN5542_Poly.tif:
# Original image bounds: BoundingBox(left=-6753.664807777929, bottom=-2922.5953576316206, right=7257.97271929253, top=14719.772744980772)
# Original image CRS: PROJCS["unnamed",GEOGCS["NAD27",DATUM["North_American_Datum_1927",SPHEROID["Clarke 1866",6378206.4,294.978698213898,AUTHORITY["EPSG","7008"]],AUTHORITY["EPSG","6267"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4267"]],PROJECTION["Polyconic"],PARAMETER["latitude_of_origin",35.125],PARAMETER["central_meridian",-119.3125],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Transformed crop bounds: (-5610.286023779871, 5.392555616654765, 5783.138921374465, 13873.534973583583)
# Cropped image shape: (4, 4557, 3745)
# Processing status: Success
#
# ==================================================
# Processing entry 40/52: 69KN5543_Poly.tif
#
# Converted coordinates:
# South: 35.125
# North: 35.25
# West: -119.25
# East: -119.125
#
# Processing 69KN5543_Poly.tif:
# Original image bounds: BoundingBox(left=-7057.492146829619, bottom=-2814.6896410296104, right=7077.1498973383395, top=14943.207228813546)
# Original image CRS: PROJCS["unnamed",GEOGCS["NAD27",DATUM["North_American_Datum_1927",SPHEROID["Clarke 1866",6378206.4,294.978698213898,AUTHORITY["EPSG","7008"]],AUTHORITY["EPSG","6267"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4267"]],PROJECTION["Polyconic"],PARAMETER["latitude_of_origin",35.125],PARAMETER["central_meridian",-119.1875],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Transformed crop bounds: (-5610.760888829888, 5.426036905955709, 5782.735593617323, 13873.679318183884)
# Cropped image shape: (4, 4567, 3752)
# Processing status: Success
#
# ==================================================
# Processing entry 41/52: 69KN5544_Poly.tif
#
# Converted coordinates:
# South: 35.125
# North: 35.25
# West: -119.125
# East: -119.0
#
# Processing 69KN5544_Poly.tif:
# Original image bounds: BoundingBox(left=-6768.208222946582, bottom=-2327.5886867142654, right=7450.300784635309, top=14944.35932186546)
# Original image CRS: PROJCS["unnamed",GEOGCS["NAD27",DATUM["North_American_Datum_1927",SPHEROID["Clarke 1866",6378206.4,294.978698213898,AUTHORITY["EPSG","7008"]],AUTHORITY["EPSG","6267"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4267"]],PROJECTION["Polyconic"],PARAMETER["latitude_of_origin",35.125],PARAMETER["central_meridian",-119.0625],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Transformed crop bounds: (-5611.164066135569, 5.546148086910156, 5782.332186376075, 13873.823086579543)
# Cropped image shape: (4, 4643, 3814)
# Processing status: Success
#
# ==================================================
# Processing entry 42/52: 69KN5545_Poly.tif
#
# Converted coordinates:
# South: 35.125
# North: 35.25
# West: -119.0
# East: -118.875
#
# Processing 69KN5545_Poly.tif:
# Original image bounds: BoundingBox(left=-6868.511189884774, bottom=-2456.789384508622, right=7183.6956723996755, top=15234.969537118046)
# Original image CRS: PROJCS["unnamed",GEOGCS["NAD27",DATUM["North_American_Datum_1927",SPHEROID["Clarke 1866",6378206.4,294.978698213898,AUTHORITY["EPSG","7008"]],AUTHORITY["EPSG","6267"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4267"]],PROJECTION["Polyconic"],PARAMETER["latitude_of_origin",35.125],PARAMETER["central_meridian",-118.9375],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Transformed crop bounds: (-5611.567323748182, 5.665605647834466, 5781.989841567411, 13873.818359269886)
# Cropped image shape: (4, 4551, 3739)
# Processing status: Success
#
# ==================================================
# Processing entry 43/52: 69KN5546_Poly.tif
#
# Converted coordinates:
# South: 35.125
# North: 35.25
# West: -118.875
# East: -118.75
#
# Processing 69KN5546_Poly.tif:
# Original image bounds: BoundingBox(left=-6879.049228712814, bottom=-2845.0290596865707, right=7227.807219385116, top=14915.445455770485)
# Original image CRS: PROJCS["unnamed",GEOGCS["NAD27",DATUM["North_American_Datum_1927",SPHEROID["Clarke 1866",6378206.4,294.978698213898,AUTHORITY["EPSG","7008"]],AUTHORITY["EPSG","6267"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4267"]],PROJECTION["Polyconic"],PARAMETER["latitude_of_origin",35.125],PARAMETER["central_meridian",-118.8125],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Transformed crop bounds: (-5611.90967045962, 5.664302811674073, 5781.64756664741, 13873.813501233415)
# Cropped image shape: (4, 4564, 3750)
# Processing status: Success
#
# ==================================================
# Processing entry 44/52: 69KN5642_Poly.tif
#
# Converted coordinates:
# South: 35.0
# North: 35.125
# West: -119.375
# East: -119.25
#
# Processing 69KN5642_Poly.tif:
# Original image bounds: BoundingBox(left=-6761.99160827049, bottom=-2650.1760677004095, right=7234.500503089815, top=15003.522822540534)
# Original image CRS: PROJCS["unnamed",GEOGCS["NAD27",DATUM["North_American_Datum_1927",SPHEROID["Clarke 1866",6378206.4,294.978698213898,AUTHORITY["EPSG","7008"]],AUTHORITY["EPSG","6267"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4267"]],PROJECTION["Polyconic"],PARAMETER["latitude_of_origin",35],PARAMETER["central_meridian",-119.3125],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Transformed crop bounds: (-5618.775680645835, 5.056697961027152, 5792.013557874115, 13872.874063296305)
# Cropped image shape: (4, 4563, 3754)
# Processing status: Success
#
# ==================================================
# Processing entry 45/52: 69KN5643_Poly.tif
#
# Converted coordinates:
# South: 35.0
# North: 35.125
# West: -119.25
# East: -119.125
#
# Processing 69KN5643_Poly.tif:
# Original image bounds: BoundingBox(left=-7078.237585845454, bottom=-2311.0467732124016, right=7201.236767361654, top=15592.2124988154)
# Original image CRS: PROJCS["unnamed",GEOGCS["NAD27",DATUM["North_American_Datum_1927",SPHEROID["Clarke 1866",6378206.4,294.978698213898,AUTHORITY["EPSG","7008"]],AUTHORITY["EPSG","6267"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4267"]],PROJECTION["Polyconic"],PARAMETER["latitude_of_origin",35],PARAMETER["central_meridian",-119.1875],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Transformed crop bounds: (-5619.26664201683, 5.054937219599328, 5791.604953085006, 13872.993668298346)
# Cropped image shape: (4, 4567, 3757)
# Processing status: Success
#
# ==================================================
# Processing entry 46/52: 69KN5644_Poly.tif
#
# Converted coordinates:
# South: 35.0
# North: 35.125
# West: -119.125
# East: -119.0
#
# Processing 69KN5644_Poly.tif:
# Original image bounds: BoundingBox(left=-6987.952481202509, bottom=-2426.2520163940553, right=7285.664449710032, top=15449.971104748807)
# Original image CRS: PROJCS["unnamed",GEOGCS["NAD27",DATUM["North_American_Datum_1927",SPHEROID["Clarke 1866",6378206.4,294.978698213898,AUTHORITY["EPSG","7008"]],AUTHORITY["EPSG","6267"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4267"]],PROJECTION["Polyconic"],PARAMETER["latitude_of_origin",35],PARAMETER["central_meridian",-119.0625],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Transformed crop bounds: (-5619.6751277710155, 5.150317993466782, 5791.195962101449, 13873.112619580654)
# Cropped image shape: (4, 4563, 3754)
# Processing status: Success
#
# ==================================================
# Processing entry 47/52: 69KN5645_Poly.tif
#
# Converted coordinates:
# South: 35.0
# North: 35.125
# West: -119.0
# East: -118.875
#
# Processing 69KN5645_Poly.tif:
# Original image bounds: BoundingBox(left=-6848.18306364235, bottom=-2765.1856658432043, right=7122.161311359469, top=14898.991881587885)
# Original image CRS: PROJCS["unnamed",GEOGCS["NAD27",DATUM["North_American_Datum_1927",SPHEROID["Clarke 1866",6378206.4,294.978698213898,AUTHORITY["EPSG","7008"]],AUTHORITY["EPSG","6267"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4267"]],PROJECTION["Polyconic"],PARAMETER["latitude_of_origin",35],PARAMETER["central_meridian",-118.9375],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Transformed crop bounds: (-5620.084000636951, 5.244967811259059, 5790.781927419435, 13873.11088701501)
# Cropped image shape: (4, 4566, 3757)
# Processing status: Success
#
# ==================================================
# Processing entry 48/52: 69KN5646_Poly.tif
#
# Converted coordinates:
# South: 35.0
# North: 35.125
# West: -118.875
# East: -118.75
#
# Processing 69KN5646_Poly.tif:
# Original image bounds: BoundingBox(left=-6748.556065804268, bottom=-2650.6949718689357, right=7251.019444085968, top=15019.556484986664)
# Original image CRS: PROJCS["unnamed",GEOGCS["NAD27",DATUM["North_American_Datum_1927",SPHEROID["Clarke 1866",6378206.4,294.978698213898,AUTHORITY["EPSG","7008"]],AUTHORITY["EPSG","6267"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4267"]],PROJECTION["Polyconic"],PARAMETER["latitude_of_origin",35],PARAMETER["central_meridian",-118.8125],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Transformed crop bounds: (-5620.498033427789, 5.246736314100108, 5790.368347480351, 13873.108642214003)
# Cropped image shape: (4, 4569, 3759)
# Processing status: Success
#
# ==================================================
# Processing entry 49/52: 69KN5743_Poly.tif
#
# Converted coordinates:
# South: 34.875
# North: 35.0
# West: -119.25
# East: -119.125
#
# Processing 69KN5743_Poly.tif:
# Original image bounds: BoundingBox(left=-7198.409031838615, bottom=-2601.2601966504226, right=7013.2229317979745, top=15222.52020750859)
# Original image CRS: PROJCS["unnamed",GEOGCS["NAD27",DATUM["North_American_Datum_1927",SPHEROID["Clarke 1866",6378206.4,294.978698213898,AUTHORITY["EPSG","7008"]],AUTHORITY["EPSG","6267"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4267"]],PROJECTION["Polyconic"],PARAMETER["latitude_of_origin",34.875],PARAMETER["central_meridian",-119.1875],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Transformed crop bounds: (-5627.767522693256, 4.486727349960496, 5800.3957892512935, 13872.30844500562)
# Cropped image shape: (4, 4566, 3762)
# Processing status: Success
#
# ==================================================
# Processing entry 50/52: 69KN5744_Poly.tif
#
# Converted coordinates:
# South: 34.875
# North: 35.0
# West: -119.125
# East: -119.0
#
# Processing 69KN5744_Poly.tif:
# Original image bounds: BoundingBox(left=-7474.010292443394, bottom=-2554.0458022486455, right=6738.6928422168, top=15241.563615017367)
# Original image CRS: PROJCS["unnamed",GEOGCS["NAD27",DATUM["North_American_Datum_1927",SPHEROID["Clarke 1866",6378206.4,294.978698213898,AUTHORITY["EPSG","7008"]],AUTHORITY["EPSG","6267"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4267"]],PROJECTION["Polyconic"],PARAMETER["latitude_of_origin",34.875],PARAMETER["central_meridian",-119.0625],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Transformed crop bounds: (-5628.210568389198, 4.524301089507922, 5799.952654780515, 13872.402583107842)
# Cropped image shape: (4, 4548, 3749)
# Processing status: Success
#
# ==================================================
# Processing entry 51/52: 69KN5745_Poly.tif
#
# Converted coordinates:
# South: 34.875
# North: 35.0
# West: -119.0
# East: -118.875
#
# Processing 69KN5745_Poly.tif:
# Original image bounds: BoundingBox(left=-7164.9020457066845, bottom=-2681.440773015489, right=6993.247928436805, top=15083.202691962055)
# Original image CRS: PROJCS["unnamed",GEOGCS["NAD27",DATUM["North_American_Datum_1927",SPHEROID["Clarke 1866",6378206.4,294.978698213898,AUTHORITY["EPSG","7008"]],AUTHORITY["EPSG","6267"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4267"]],PROJECTION["Polyconic"],PARAMETER["latitude_of_origin",34.875],PARAMETER["central_meridian",-118.9375],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Transformed crop bounds: (-5628.653656522481, 4.561725150053706, 5799.496803385866, 13872.403833508999)
# Cropped image shape: (4, 4558, 3756)
# Processing status: Success
#
# ==================================================
# Processing entry 52/52: 69KN5746_Poly.tif
#
# Converted coordinates:
# South: 34.875
# North: 35.0
# West: -118.875
# East: -118.75
#
# Processing 69KN5746_Poly.tif:
# Original image bounds: BoundingBox(left=-7268.613082814368, bottom=-2826.0871993325018, right=6831.354844395096, top=14901.49809625326)
# Original image CRS: PROJCS["unnamed",GEOGCS["NAD27",DATUM["North_American_Datum_1927",SPHEROID["Clarke 1866",6378206.4,294.978698213898,AUTHORITY["EPSG","7008"]],AUTHORITY["EPSG","6267"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4267"]],PROJECTION["Polyconic"],PARAMETER["latitude_of_origin",34.875],PARAMETER["central_meridian",-118.8125],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Transformed crop bounds: (-5629.109534216264, 4.5409252785754175, 5799.041719133287, 13872.404191062134)
# Cropped image shape: (4, 4562, 3759)
# Processing status: Success
#
# ==================================================
# Processing Summary:
# Total files in Excel: 52
# Previously processed: 0
# Newly processed this run: 52
# Total successful: 49
# Total failed: 3
# Summary saved to: outputs/outputs_1969/processing_results.csv
